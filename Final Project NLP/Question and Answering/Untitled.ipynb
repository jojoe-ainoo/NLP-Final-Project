# %%
import nltk
nltk.download('averaged_perceptron_tagger')
import sklearn
#Import  CountVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import random
import string
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
# Import Multinominal Naive Bayes Model
from sklearn.naive_bayes import MultinomialNB

#Import train_test_split to split dataset into training and testing sets
from sklearn.model_selection import train_test_split

from sklearn.metrics.pairwise import cosine_similarity
import re
#import pyrata.re as pyrata_re
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/Nana/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
f=open('../FAQs/Questions.txt','r',errors = 'ignore')
t=open('../FAQs/Answers.txt','r',errors = 'ignore')

# %%
#listObj = line.lower().split()

def createSentence(T):
    ray = ["\twhat","\twhen","\twhere","\thow","\twhere","\twhich","\thow","\twho","\twhose","\twhom","is","are","the","an","it","is","\n",'ï»¿',"\t",".","!"]
    Fo = open(T,"r")
    listObj = []
    newObj = []
    sent = ""
    line = Fo.readline()
    while(len(line) != 0 ):
        listObj = line.lower().split(" ")
        for i in ray:
            if(i in listObj):

                listObj.remove(i)
        for t in listObj:
            sent =sent +" " + t +" "
        newObj.append(sent)
        sent = ""
        line = Fo.readline()
    Fo.close()
    #print(newObj)
    return(newObj)

 
def removeNum(text):
    numReg = re.compile(r'^(\d+\.?)')
    for i in range(len(text)-1):
        text[i] = numReg.sub('',text[i])
    return text
    



def naiveNormalized(test):
    # normalize data
    review_vec = CountVectorizer(min_df=1, tokenizer=nltk.word_tokenize)
    Question = createSentence('../FAQs/Questions.txt')
    
    Answers = createSentence('../FAQs/Answers.txt')
    Question = removeNum(Question)
    Answers = removeNum(Answers)
    print(Question)

    testdoc = createSentence(test)
   #counterAnswer = review_vec.fit
    counterQuestion = review_vec.fit_transform(Question)
    counterTestdoc = review_vec.transform(testdoc)
   
    
   
        
    
    
    
    #Converting raw frequency counts into TF-IDF values
    tfidf_transformer = TfidfTransformer()
    review_tfidf = tfidf_transformer.fit_transform(counterQuestion)
    
    
    review_tfidf2 = tfidf_transformer.fit_transform(counterTestdoc)
    

    # Split data into training and test sets
    X_trainset, X_testset,Y_trainset, Y_testset  = train_test_split(review_tfidf, Answers, train_size = 0.80, random_state = 12)
    #testd = train_test_split(review_tfidf, testdoc, test_size = 1, random_state = 12)

    
    #print(docs_test)
    # Train Naive Bayes classifier
    trainer = MultinomialNB().fit(X_trainset, Y_trainset)

    # Predicting the Test set results
    pred = trainer.predict(review_tfidf2)

    #calculate accuracy
    #print('Accuracy on the test subset for Naive Bayes is: {:.3f}'.format(sklearn.metrics.accuracy_score(y_test, y_pred)))


    
    print(pred)

    
naiveNormalized("qatest.txt")
# Out:
# [' 1.\thow  many  regions  in  ghana?\n ', ' 2.\twhat  favorite  food  for  people  in  ashanti  region  of  ghana?\n ', ' 3.\twhat  name  of  the  king  of  the  asantes?\n ', ' 4.\twhat  cash  crop  does  ghana  export?\n ', ' 5.\twhat  primary  occupation  in  ghana?\n ', ' 6.\twhich  country  leading  producer  of  cocoa  in  africa?\n ', ' 7.\twho  minister  of  food  and  agriculture  in  ghana?\n ', ' 8.\twhat  crop  rotation?\n ', ' 9.\twhat  a  cash  crop?\n ', ' 10.\twhat  arable  farming?\n ', ' 11.\twhat  dominant  native  language  in  ghana?\n ', ' 12.\twhat  current  population  of  ghana?\n ', ' 13.\twhat  capital  city  of  ghana?\n ', ' 14.\twhere  golf  mined  in  ashanti  region?\n ', ' 15.\tghana  in  which  part  of  africa?\n ', ' 16.\twhat  southest  point  in  ghana?\n ', ' 17.\twhich  year  did  ghana  gain  independence?\n ', ' 18.\twhich  region  in  ghana  has  largest  population?\n ', ' 19.\twhat  world  population  in  2018?\n ', ' 20.\twhich  richest  country  in  the  world?\n ', ' 21.\twhich  food  nutrient  in  cooked  yam?\n ', ' 22.\twhich  food  nutrient  in  fried  meat?\n ', ' 23.\twhich  food  nutrient  in  groundnuts?\n ', ' 24.\twhich  type  of  vitamins  helps  blood  clotting?\n ', ' 25.\twhich  type  of  vitamins  helps  scurvy?\n ', ' 26.\twhich  largest  ethnic  group  in  ghana?\n ', ' 27.\twhich  people  celebrate  homowo  festival?\n ', ' 28.\twhich  city  in  ghana  has  largest  population?\n ', ' 29.\thow  many  religions  in  ghana?\n ', ' 30.\twhere  cattle  dominantly  reared  in  ghana?\n ', ' 31.\thow  many  lakes  in  ghana?\n ', ' 32.\twhich  country  ashesi  university  found?\n ', ' 33.\thow  many  countries  in  africa?\n ', ' 34.\twhat  most  popular  name  for  mini  commercial  vehicles  in  ghana?\n ', ' 35.\twhich  professionals  work  in  hospital?\n ', ' 36.\twhich  people  always  on  pitch  when  one  goes  to  the  stadium?\n ', ' 37.\twhat  new  terminal  opened  in  accra?\n ', ' 38.\twhich  richest  country  in  africa?\n ', ' 39.\twhich  transport  company  mostly  popular  in  accra  and  kumasi?\n ', ' 40.\twhich  dam  supplies  electricity  to  ghana?\n ', ' 41.\twhich  country  colonised  kenya?\n ', ' 42.\twhen  did  kenya  gain  its  independence?\n ', ' 43.\twhat  capital  city  of  kenya?\n ', ' 44.\twhich  continent  kenya  in?\n ', ' 45.\tdoes  equator  pass  through  kenya?\n ', ' 46.\twhich  countries  does  kenya  border?\n ', ' 47.\twhat  current  population  of  kenya?\n ', ' 48.\twhich  oldest  city  in  kenya?\n ', ' 49.\twhich  secold  largest  city  in  kenya?\n ', ' 50.\tis  kenya  part  of  african  great  lakes  region?\n ', ' 51.\twho  was  first  president  of  kenya?\n ', ' 52.\twho  was  second  president  of  kenya?\n ', ' 53.\twho  was  third  president  of  kenya?\n ', ' 54.\twho  current  president  of  kenya?\n ', ' 55.\thow  many  presidents  has  kenya  had  since  independence?\n ', ' 56.\twho  comander  in  chief  of  the  kenya  defence  forces?\n ', ' 57.\twhat  largest  source  of  foreign  exchange  revenue  in  kenya?\n ', ' 58.\twhat  second  largest  source  of  foreign  exchange  revenue  in  kenya?\n ', ' 59.\twhat  percentage  does  agriculture  constitute  gdp  in  kenya?\n ', ' 60.\twhat  percentage  does  manufacturing  constitute  gdp  in  kenya?\n ', ' 61.\thow  many  airports  does  kenya  have?\n ', " 62.\twhere  does  largest  share  of  kenya's  electricity  supply  comes  from?\n ", " 63.\twhat  kenya's  gdp?\n ", " 64.\twhat  kenya's  annual  growth  rate?\n ", ' 65.\twhat  three  main  cash  crops  exported  from  kenya?\n ', " 66.\twhat  percentage  of  kenya's  population  below  30  years?\n ", ' 67.\twhat  largest  native  ethnic  group  in  kenya?\n ', ' 68.\twhat  official  language  in  kenya?\n ', ' 69.\twhich  main  religion  in  kenya?\n ', ' 70.\twhich  second  largest  religion  in  kenya?\n ', ' 71.\twhat  total  fertility  rate  in  kenya?\n ', ' 72.\twhat  education  system  doe ...
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2069: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# [' yes\n ' ' yes\n ' ' yes\n ']
